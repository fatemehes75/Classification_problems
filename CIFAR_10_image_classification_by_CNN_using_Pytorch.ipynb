# %% [markdown]
# <a href="https://colab.research.google.com/github/fatemehes75/Classification_problems/blob/main/CIFAR_10_image_classification_by_CNN_using_Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## About Dataset
# The CIFAR-10 dataset consists of *60000 32x32* colour images in *10* classes. There are 50000 training images and 10000 test images.
#
# The dataset is divided into *five training batches* and *one test batch*, *each with 10000 images*.

# %% [markdown]
# ![Example-of-a-CNN-for-the-Image-Classification-task-on-CIFAR10-dataset.pbm](data:application/octet-stream;base64,...)
#
# Example of a CNN for the Image Classification task on CIFAR10 dataset

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# dataset images have of range [0, 1] => transform them to normalized Tensors with range [-1, 1]

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_dataset = torchvision.datasets.CIFAR10('data', train=True,
                                        download=True, transform=transform)

test_dataset = torchvision.datasets.CIFAR10('data', train=False,
                                       download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=16,
                                          shuffle=True)

test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=16,
                                         shuffle=False)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# ...
# 100%|██████████| 170498071/170498071 [00:03<00:00, 49960652.41it/s]
# Extracting data/cifar-10-python.tar.gz to data
# Files already downloaded and verified

# %%
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        self.network = nn.Sequential(
        # origin shape: [4, 3, 32, 32] = 4, 3, 1024
        # ((W - F +2P)S)+1 
        nn.Conv2d(3, 6, 5), #(input-size, output_size, kernel_size)
        nn.ReLU(),
        nn.MaxPool2d(2, 2),
        #size(14,14,6)

        nn.Conv2d(6, 16, 5),
        nn.ReLU(),
        nn.MaxPool2d(2, 2),
        #size(5,5,16)

            nn.Flatten(), 
            nn.Linear(400, 120),
            nn.ReLU(),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Linear(84, 10))

    def forward(self, xb):
        return self.network(xb)


model = ConvNet().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)


number_epochs = 5
for epoch in range(number_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i+1) % 3125 == 0:
            print (f'Epoch [{epoch+1}/{number_epochs}], Step [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}')



#Evaluation
with torch.no_grad():
    n_correct = 0
    n_samples = 0
    n_class_correct = [0 for i in range(10)]
    n_class_samples = [0 for i in range(10)]
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        # max returns (value ,index)
        _, predicted = torch.max(outputs, 1)
        n_samples += labels.size(0)
        n_correct += (predicted == labels).sum().item()
        
        for i in range(16):
            label = labels[i]
            pred = predicted[i]
            if (label == pred):
                n_class_correct[label] += 1
            n_class_samples[label] += 1

    acc = 100.0 * n_correct / n_samples
    print(f'Accuracy of the network: {acc} %')

    for i in range(10):
        acc = 100.0 * n_class_correct[i] / n_class_samples[i]
        print(f'Accuracy of {classes[i]}: {acc} %')
# Out:
# Epoch [1/5], Step [3125/3125], Loss: 1.5201
# Epoch [2/5], Step [3125/3125], Loss: 1.4887
# Epoch [3/5], Step [3125/3125], Loss: 0.9063
# Epoch [4/5], Step [3125/3125], Loss: 0.9957
# Epoch [5/5], Step [3125/3125], Loss: 1.0165
# Accuracy of the network: 57.72 %
# Accuracy of plane: 75.1 %
# Accuracy of car: 68.2 %
# Accuracy of bird: 40.5 %
# Accuracy of cat: 21.6 %
# Accuracy of deer: 42.4 %
# Accuracy of dog: 55.6 %
# Accuracy of frog: 80.3 %
# Accuracy of horse: 61.4 %
# Accuracy of ship: 62.6 %
# Accuracy of truck: 69.5 %
